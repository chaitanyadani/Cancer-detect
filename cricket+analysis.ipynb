# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
matches = pd.read_csv("C:/Users/MIT/Desktop/3rd Sem Dani/CSV files/matches.csv")

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
# id                 636 non-null int64
# season             636 non-null int64
# city               629 non-null object
# date               636 non-null object
# team1              636 non-null object
# team2              636 non-null object
# toss_winner        636 non-null object
# toss_decision      636 non-null object
# result             636 non-null object
# dl_applied         636 non-null int64
# winner             633 non-null object
# win_by_runs        636 non-null int64
# win_by_wickets     636 non-null int64
# player_of_match    633 non-null object
# venue              636 non-null object
# umpire1            635 non-null object
# umpire2            635 non-null object
# umpire3            0 non-null float64
# dtypes: float64(1), int64(5), object(12)
# memory usage: 89.5+ KB

# %%
matches[pd.isnull(matches['winner'])]
# Out:
#       id  season       city        date                        team1  \
# 300  301    2011      Delhi  2011-05-21             Delhi Daredevils
# 545  546    2015  Bangalore  2015-04-29  Royal Challengers Bangalore
# 570  571    2015  Bangalore  2015-05-17             Delhi Daredevils
#
#                            team2                  toss_winner toss_decision  \
# 300                Pune Warriors             Delhi Daredevils           bat
# 545             Rajasthan Royals             Rajasthan Royals         field
# 570  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#         result  dl_applied winner  win_by_runs  win_by_wickets  \
# 300  no result           0    NaN            0               0
# 545  no result           0    NaN            0               0
# 570  no result           0    NaN            0               0
#
#     player_of_match                  venue          umpire1       umpire2  \
# ...

# %%
matches['winner'].fillna('Draw', inplace=True)

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
# id                 636 non-null int64
# season             636 non-null int64
# city               629 non-null object
# date               636 non-null object
# team1              636 non-null object
# team2              636 non-null object
# toss_winner        636 non-null object
# toss_decision      636 non-null object
# result             636 non-null object
# dl_applied         636 non-null int64
# winner             636 non-null object
# win_by_runs        636 non-null int64
# win_by_wickets     636 non-null int64
# player_of_match    633 non-null object
# venue              636 non-null object
# umpire1            635 non-null object
# umpire2            635 non-null object
# umpire3            0 non-null float64
# dtypes: float64(1), int64(5), object(12)
# memory usage: 89.5+ KB

# %%
matches.replace(['Mumbai Indians','Kolkata Knight Riders','Royal Challengers Bangalore','Deccan Chargers','Chennai Super Kings',
                 'Rajasthan Royals','Delhi Daredevils','Gujarat Lions','Kings XI Punjab',
                 'Sunrisers Hyderabad','Rising Pune Supergiants','Rising Pune Supergiant','Kochi Tuskers Kerala','Pune Warriors']
                ,['MI','KKR','RCB','DC','CSK','RR','DD','GL','KXIP','SRH','RPS','RPS','KTK','PW'],inplace=True)

# %%
matches['team1'].unique().sort()

# %%
matches['team2'].unique()
# Out:
# array(['RCB', 'RPS', 'KKR', 'KXIP', 'DD', 'SRH', 'MI', 'GL', 'RR', 'CSK',
#        'DC', 'PW', 'KTK'], dtype=object)

# %%
encode = {'team1': {'MI':1,'KKR':2,'RCB':3,'DC':4,'CSK':5,'RR':6,'DD':7,'GL':8,'KXIP':9,'SRH':10,'RPS':11,'KTK':12,'PW':13},
          'team2': {'MI':1,'KKR':2,'RCB':3,'DC':4,'CSK':5,'RR':6,'DD':7,'GL':8,'KXIP':9,'SRH':10,'RPS':11,'KTK':12,'PW':13},
          'toss_winner': {'MI':1,'KKR':2,'RCB':3,'DC':4,'CSK':5,'RR':6,'DD':7,'GL':8,'KXIP':9,'SRH':10,'RPS':11,'KTK':12,'PW':13},
          'winner': {'MI':1,'KKR':2,'RCB':3,'DC':4,'CSK':5,'RR':6,'DD':7,'GL':8,'KXIP':9,'SRH':10,'RPS':11,'KTK':12,'PW':13,'Draw':14}}

# %%
matches.replace(encode, inplace = True)

# %%
matches.head()
# Out:
#    id  season       city        date  team1  team2  toss_winner toss_decision  \
# 0   1    2017  Hyderabad  2017-04-05     10      3            3         field
# 1   2    2017       Pune  2017-04-06      1     11           11         field
# 2   3    2017     Rajkot  2017-04-07      8      2            2         field
# 3   4    2017     Indore  2017-04-08     11      9            9         field
# 4   5    2017  Bangalore  2017-04-08      3      7            3           bat
#
#    result  dl_applied  winner  win_by_runs  win_by_wickets player_of_match  \
# 0  normal           0      10           35               0    Yuvraj Singh
# 1  normal           0      11            0               7       SPD Smith
# 2  normal           0       2            0              10         CA Lynn
# 3  normal           0       9            0               6      GJ Maxwell
# 4  normal           0       3           15               0       KM Jadhav
#
# ...

# %%
matches[pd.isnull(matches['city'])]
# Out:
#       id  season city        date  team1  team2  toss_winner toss_decision  \
# 461  462    2014  NaN  2014-04-19      1      3            3         field
# 462  463    2014  NaN  2014-04-19      2      7            2           bat
# 466  467    2014  NaN  2014-04-23      5      6            6         field
# 468  469    2014  NaN  2014-04-25     10      7           10           bat
# 469  470    2014  NaN  2014-04-25      1      5            1           bat
# 474  475    2014  NaN  2014-04-28      3      9            9         field
# 476  477    2014  NaN  2014-04-30     10      1            1         field
#
#      result  dl_applied  winner  win_by_runs  win_by_wickets player_of_match  \
# 461  normal           0       3            0               7        PA Patel
# 462  normal           0       7            0               4       JP Duminy
# 466  normal           0       5            7               0       RA Jadeja
# ...

# %%
matches['city'].fillna('Dubai', inplace = True)

# %%
matches['city'].unique()
# Out:
# array(['Hyderabad', 'Pune', 'Rajkot', 'Indore', 'Bangalore', 'Mumbai',
#        'Kolkata', 'Delhi', 'Chandigarh', 'Kanpur', 'Jaipur', 'Chennai',
#        'Cape Town', 'Port Elizabeth', 'Durban', 'Centurion', 'East London',
#        'Johannesburg', 'Kimberley', 'Bloemfontein', 'Ahmedabad', 'Cuttack',
#        'Nagpur', 'Dharamsala', 'Kochi', 'Visakhapatnam', 'Raipur',
#        'Ranchi', 'Abu Dhabi', 'Sharjah', 'Dubai'], dtype=object)

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
# id                 636 non-null int64
# season             636 non-null int64
# city               636 non-null object
# date               636 non-null object
# team1              636 non-null int64
# team2              636 non-null int64
# toss_winner        636 non-null int64
# toss_decision      636 non-null object
# result             636 non-null object
# dl_applied         636 non-null int64
# winner             636 non-null int64
# win_by_runs        636 non-null int64
# win_by_wickets     636 non-null int64
# player_of_match    636 non-null object
# venue              636 non-null object
# umpire1            636 non-null object
# umpire2            636 non-null object
# umpire3            636 non-null object
# dtypes: int64(9), object(9)
# memory usage: 89.5+ KB

# %%
matches.describe()
# Out:
#                id       season       team1       team2  toss_winner  \
# count  636.000000   636.000000  636.000000  636.000000   636.000000
# mean   318.500000  2012.490566    5.540881    5.511006     5.371069
# std    183.741666     2.773026    3.329169    3.341677     3.293140
# min      1.000000  2008.000000    1.000000    1.000000     1.000000
# 25%    159.750000  2010.000000    3.000000    3.000000     2.000000
# 50%    318.500000  2012.000000    5.000000    5.000000     5.000000
# 75%    477.250000  2015.000000    9.000000    8.000000     7.250000
# max    636.000000  2017.000000   13.000000   13.000000    13.000000
#
#        dl_applied      winner  win_by_runs  win_by_wickets
# count  636.000000  636.000000   636.000000      636.000000
# mean     0.025157    5.309748    13.682390        3.372642
# std      0.156726    3.288726    23.908877        3.420338
# min      0.000000    1.000000     0.000000        0.000000
# ...

# %%
dicval = encode['winner']

# %%
print(dicval['MI'])
# Out:
# 1

# %%
print(list(dicval.keys())[list(dicval.values()).index(1)])
# Out:
# MI

# %%
matches = matches[['team1', 'team2', 'city','toss_winner', 'toss_decision', 'venue','winner' ]]

# %%
matches.head(2)
# Out:
#    team1  team2       city  toss_winner toss_decision  \
# 0     10      3  Hyderabad            3         field
# 1      1     11       Pune           11         field
#
#                                        venue  winner
# 0  Rajiv Gandhi International Stadium, Uppal      10
# 1    Maharashtra Cricket Association Stadium      11

# %%
df = pd.DataFrame(matches)

# %%
df
# Out:
#      team1  team2           city  toss_winner toss_decision  \
# 0       10      3      Hyderabad            3         field
# 1        1     11           Pune           11         field
# 2        8      2         Rajkot            2         field
# 3       11      9         Indore            9         field
# 4        3      7      Bangalore            3           bat
# 5        8     10      Hyderabad           10         field
# 6        2      1         Mumbai            1         field
# 7        3      9         Indore            3           bat
# 8        7     11           Pune           11         field
# 9       10      1         Mumbai            1         field
# 10       9      2        Kolkata            2         field
# 11       3      1      Bangalore            1         field
# 12      11      8         Rajkot            8         field
# 13       2     10        Kolkata           10         field
# 14       7      9          Delhi            7           bat
# ...

# %%
df.shape
# Out:
# (636, 7)

# %%
df.describe()
# Out:
#             team1       team2  toss_winner      winner
# count  636.000000  636.000000   636.000000  636.000000
# mean     5.540881    5.511006     5.371069    5.309748
# std      3.329169    3.341677     3.293140    3.288726
# min      1.000000    1.000000     1.000000    1.000000
# 25%      3.000000    3.000000     2.000000    2.000000
# 50%      5.000000    5.000000     5.000000    5.000000
# 75%      9.000000    8.000000     7.250000    8.000000
# max     13.000000   13.000000    13.000000   14.000000

# %%
temp1 = df['toss_winner'].value_counts(sort = True)
temp2 = df['winner'].value_counts(sort = True)

print("Number of toss winners")
for idx, val in temp1.iteritems():
    print('{} -> {}'.format(list(dicval.keys())[list(dicval.values()).index(idx)], val))
# Out:
# Number of toss winners
# MI -> 85
# KKR -> 78
# DD -> 72
# RCB -> 70
# KXIP -> 68
# CSK -> 66
# RR -> 63
# DC -> 43
# SRH -> 35
# PW -> 20
# GL -> 15
# RPS -> 13
# KTK -> 8

# %%
print("number of match winner")
for idx, val in temp2.iteritems():
    print('{} -> {}'.format(list(dicval.keys())[list(dicval.values()).index(idx)], val))
# Out:
# number of match winner
# MI -> 92
# CSK -> 79
# KKR -> 77
# RCB -> 73
# KXIP -> 70
# RR -> 63
# DD -> 62
# SRH -> 42
# DC -> 29
# RPS -> 15
# GL -> 13
# PW -> 12
# KTK -> 6
# Draw -> 3

# %%
# %matplotlib inline
df['winner'].hist(bins = 50)
df.plot

# %%
fig = plt.figure(figsize=(8, 4))
ax1 = fig.add_subplot(121)
ax1.set_xlabel("Team")
ax1.set_ylabel("count of toss win")
ax1.set_title("toss winner")
temp1.plot(kind = 'bar')

# %%
ax2 = fig.add_subplot(122)
temp2.plot(kind = 'bar')
ax2.set_xlabel('Team')
ax2.set_ylabel('count of matches won')
ax2.set_title("Match winners")
# Out:
# Text(0.5,1,'Match winners')

# %%
df.apply(lambda x: sum(x.isnull()), axis = 0)
# Out:
# team1            0
# team2            0
# city             0
# toss_winner      0
# toss_decision    0
# venue            0
# winner           0
# dtype: int64

# %%
df[pd.isnull(df['city'])]
# Out:
# Empty DataFrame
# Columns: [team1, team2, city, toss_winner, toss_decision, venue, winner]
# Index: []

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
var_mod = ['city', 'venue', 'toss_decision']
for i in var_mod:
    df[i] = le.fit_transform(df[i])

# %%
df.dtypes
# Out:
# team1            int64
# team2            int64
# city             int64
# toss_winner      int64
# toss_decision    int64
# venue            int64
# winner           int64
# dtype: object

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import KFold   #For K-fold cross validation
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import metrics

#Generic function for making a classification model and accessing performance:
def classification_model(model, data, predictors, outcome):
  model.fit(data[predictors],data[outcome])
  predictions = model.predict(data[predictors])
  accuracy = metrics.accuracy_score(predictions,data[outcome])
  print('Accuracy : %s' % '{0:.3%}'.format(accuracy))
  kf = KFold(data.shape[0], n_folds=7)
  error = []
  for train, test in kf:
    train_predictors = (data[predictors].iloc[train,:])
    train_target = data[outcome].iloc[train]
    model.fit(train_predictors, train_target)
    error.append(model.score(data[predictors].iloc[test,:], data[outcome].iloc[test]))
 
  print('Cross-Validation Score : %s' % '{0:.3%}'.format(np.mean(error)))

  model.fit(data[predictors],data[outcome])
# Out:
# C:\Users\MIT\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from sklearn.ensemble import RandomForestRegressor
outcome_var = ['winner']
predictor_var = ['team1', 'team2', 'toss_winner']
model = LogisticRegression()
classification_model(model, df, predictor_var, outcome_var)
# Out:
# C:\Users\MIT\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Accuracy : 23.270%
# Cross-Validation Score : 21.852%

# %%
df.head(3)
# Out:
#    team1  team2  city  toss_winner  toss_decision  venue  winner
# 0     10      3    14            3              1     23      10
# 1      1     11    25           11              1     16      11
# 2      8      2    27            2              1     25       2

# %%
model = RandomForestClassifier(n_estimators = 100)
outcome_var = ['winner']
predictor_var = ['team1', 'team2', 'venue', 'city', 'toss_decision', 'toss_winner']
classification_model(model, df, predictor_var, outcome_var)
# Out:
# C:\Users\MIT\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if __name__ == '__main__':
# Accuracy : 89.151%
# C:\Users\MIT\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# C:\Users\MIT\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# C:\Users\MIT\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ...

# %%
df.head(5)
# Out:
#    team1  team2  city  toss_winner  toss_decision  venue  winner
# 0     10      3    14            3              1     23      10
# 1      1     11    25           11              1     16      11
# 2      8      2    27            2              1     25       2
# 3     11      9    15            9              1     11       9
# 4      3      7     2            3              0     14       3

# %%
team1='RCB'
team2='KKR'
toss_winner='RCB'
input=[dicval[team1],dicval[team2],'14',dicval[toss_winner],'2','1']
input = np.array(input).reshape((1, -1))
output=model.predict(input)
print(list(dicval.keys())[list(dicval.values()).index(output)])
# Out:
# KKR

# %%
team1 = 'DC'
team2 = 'DD'
toss_winner = 'DC'
input = [dicval[team1], [dicval[team2]], '17', dicval[toss_winner],'10', '0']
input = np.array(input).reshape((1, -1))
output = model.predict(input)
print(list(dicval.keys())[list(dicval.values()).index(output)])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-9ccae724d0f5> in <module>()
#       3 toss_winner = 'DC'
#       4 input = [dicval[team1], [dicval[team2]], '17', dicval[toss_winner],'10', '0']
# ----> 5 input = np.array(input).reshape((1, -1))
#       6 output = model.predict(input)
#       7 print(list(dicval.keys())[list(dicval.values()).index(output)])
#
# ValueError: setting an array element with a sequence

# %%
imp_input = pd.Series(model.feature_importances_, index=predictor_var).sort_values(ascending=False)
print(imp_input)
# Out:
# team2            0.248336
# team1            0.223957
# toss_winner      0.169067
# venue            0.167971
# city             0.157042
# toss_decision    0.033627
# dtype: float64

# %%
import matplotlib.pyplot as mlt
mlt.style.use('fivethirtyeight')
df_fil=df[df['toss_winner']==df['winner']]
slices=[len(df_fil),(577-len(df_fil))]
mlt.pie(slices,labels=['Toss & win','Toss & lose'],startangle=90,shadow=True,explode=(0,0),autopct='%1.1f%%',colors=['r','w'])
fig = mlt.gcf()
fig.set_size_inches(6,6)
mlt.show()

# %%
import seaborn as sns
team1=dicval['MI']
team2=dicval['CSK']
mtemp=matches[((matches['team1']==team1)|(matches['team2']==team1))&((matches['team1']==team2)|(matches['team2']==team2))]
sns.countplot(x='venue', hue='winner',data=mtemp,palette='Set1')
mlt.xticks(rotation='horizontal')
leg = mlt.legend( loc = 'upper right')
fig=mlt.gcf()
fig.set_size_inches(10,6)
mlt.show()
